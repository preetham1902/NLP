# %%
# TASK 5: CHINESE SEGMENTATION USING JIEBA
# !pip install jieba

# %%
import jieba
seg=jieba.cut("把句子中所有的可以成词的词语都扫描出来",cut_all=True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\saipreetham\AppData\Local\Temp\jieba.cache
# Loading model cost 0.853 seconds.
# Prefix dict has been built successfully.
# 把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来

# %%
#TASK 1: BASIC TEXT PROCESSING PIPELINE

import nltk
texts="""Who owns Wikipedia? Who owns the Web site? Wikipedia's tech framework is supported by a non-profit parent organization, the Wikimedia Foundation Inc, which also supports Wikipedia's sister projects, including Wiktionary (a wiki dictionary), Wikibooks (textbooks), and others, and owns all of their domain names"""

for text in texts:
    sentences=nltk.sent_tokenize(texts)
    for sentence in sentences:
        words=nltk.word_tokenize(sentence)
        tagged=nltk.pos_tag(words)
        print(tagged)
# Out:
# [('Who', 'WP'), ('owns', 'VBZ'), ('Wikipedia', 'NNP'), ('?', '.')]
# [('Who', 'WP'), ('owns', 'VBZ'), ('the', 'DT'), ('Web', 'NNP'), ('site', 'NN'), ('?', '.')]
# [('Wikipedia', 'NNP'), ("'s", 'POS'), ('tech', 'NN'), ('framework', 'NN'), ('is', 'VBZ'), ('supported', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('non-profit', 'JJ'), ('parent', 'NN'), ('organization', 'NN'), (',', ','), ('the', 'DT'), ('Wikimedia', 'NNP'), ('Foundation', 'NNP'), ('Inc', 'NNP'), (',', ','), ('which', 'WDT'), ('also', 'RB'), ('supports', 'VBZ'), ('Wikipedia', 'NNP'), ("'s", 'POS'), ('sister', 'NN'), ('projects', 'NNS'), (',', ','), ('including', 'VBG'), ('Wiktionary', 'NNP'), ('(', '('), ('a', 'DT'), ('wiki', 'NN'), ('dictionary', 'NN'), (')', ')'), (',', ','), ('Wikibooks', 'NNP'), ('(', '('), ('textbooks', 'NN'), (')', ')'), (',', ','), ('and', 'CC'), ('others', 'NNS'), (',', ','), ('and', 'CC'), ('owns', 'VBZ'), ('all', 'DT'), ('of', 'IN'), ('their', 'PRP$'), ('domain', 'NN'), ('names', 'NNS')]
# ...

# %%
#TASK 2" TweetTokenizer

import nltk
from nltk.tokenize import TweetTokenizer
text='The Party was sooo fun :D  #superfun'
twtkn=TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'Party', 'was', 'sooo', 'fun', ':D', '#superfun']

# %%
#TASK 3: SCRAPING DATA FROM WEB

from urllib import request
url="http://www.gutenberg.org/files/2554/2554-0.txt"
response=request.urlopen(url)
raw=response.read().decode('utf8')
type(raw)
print(raw[:50])
from nltk.tokenize import word_tokenize
tokens=word_tokenize(raw)
type(tokens)
# Out:
# ﻿The Project Gutenberg EBook of Crime and Punishme
# list

# %%
text = ' '.join(tokens)
type(text)
# Out:
# str

# %%
vocab = nltk.FreqDist(tokens)
print(type(vocab.keys()))
print(type(vocab))
# Out:
# <class 'dict_keys'>
# <class 'nltk.probability.FreqDist'>

# %%
vocab
# Out:
# FreqDist({',': 16178, '.': 9589, 'the': 7436, 'and': 6284, 'to': 5278, 'a': 4469, 'I': 4397, '’': 4046, '“': 3991, '”': 3940, ...})
